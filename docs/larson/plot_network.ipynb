# %%
import numpy as np
import pandas as pd
import networkx as nx
import seaborn as sns
import graspologic
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [2], in <module>
#       3 import networkx as nx
#       4 import seaborn as sns
# ----> 5 import graspologic
#       6 from datetime import datetime
#
# File c:\Users\austi\OneDrive\Documents\github\networks-course\venv\lib\site-packages\graspologic\__init__.py:8, in <module>
#       6 import graspologic.datasets
#       7 import graspologic.embed
# ----> 8 import graspologic.inference
#       9 import graspologic.layouts
#      10 import graspologic.models
#
# File c:\Users\austi\OneDrive\Documents\github\networks-course\venv\lib\site-packages\graspologic\inference\__init__.py:4, in <module>
#       1 # Copyright (c) Microsoft Corporation and contributors.
#       2 # Licensed under the MIT License.
# ----> 4 from .latent_distribution_test import latent_distribution_test
#       5 from .latent_position_test import latent_position_test
#       7 __all__ = ["latent_position_test", "latent_distribution_test"]
#
# File c:\Users\austi\OneDrive\Documents\github\networks-course\venv\lib\site-packages\graspologic\inference\latent_distribution_test.py:7, in <module>
#       4 from collections import namedtuple
#       6 import numpy as np
# ----> 7 from hyppo.ksample import KSample
#       8 from joblib import Parallel, delayed
#       9 from scipy import stats
#
# File c:\Users\austi\OneDrive\Documents\github\networks-course\venv\lib\site-packages\hyppo\__init__.py:1, in <module>
# ----> 1 import hyppo.discrim
#       2 import hyppo.independence
#       3 import hyppo.ksample
#
# File c:\Users\austi\OneDrive\Documents\github\networks-course\venv\lib\site-packages\hyppo\discrim\__init__.py:1, in <module>
# ----> 1 from .discrim_one_samp import DiscrimOneSample
#       2 from .discrim_two_samp import DiscrimTwoSample
#       4 __all__ = [s for s in dir()]
#
# File c:\Users\austi\OneDrive\Documents\github\networks-course\venv\lib\site-packages\hyppo\discrim\discrim_one_samp.py:5, in <module>
#       3 import numpy as np
#       4 from scipy._lib._util import MapWrapper
# ----> 5 from ._utils import _CheckInputs
#       6 from .base import DiscriminabilityTest
#       7 from sklearn.utils import check_random_state
#
# File c:\Users\austi\OneDrive\Documents\github\networks-course\venv\lib\site-packages\hyppo\discrim\_utils.py:4, in <module>
#       1 import numpy as np
#       2 from sklearn.metrics import pairwise_distances
# ----> 4 from ..tools import check_ndarray_xy, check_reps, contains_nan, convert_xy_float64
#       7 class _CheckInputs:
#       8     """Checks inputs for discriminability tests"""
#
# File c:\Users\austi\OneDrive\Documents\github\networks-course\venv\lib\site-packages\hyppo\tools\__init__.py:4, in <module>
#       2 from .indep_sim import *
#       3 from .ksample_sim import *
# ----> 4 from .power import *
#       5 from .time_series_sim import *
#       7 __all__ = [s for s in dir() if not s.startswith("_")]
#
# File c:\Users\austi\OneDrive\Documents\github\networks-course\venv\lib\site-packages\hyppo\tools\power.py:5, in <module>
#       1 from math import ceil
#       3 import numpy as np
# ----> 5 from ..independence import INDEP_TESTS
#       6 from ..ksample import KSAMP_TESTS, KSample, k_sample_transform
#       7 from .indep_sim import indep_sim
#
# File c:\Users\austi\OneDrive\Documents\github\networks-course\venv\lib\site-packages\hyppo\independence\__init__.py:3, in <module>
#       1 from ._utils import sim_matrix
#       2 from .cca import CCA
# ----> 3 from .dcorr import Dcorr
#       4 from .hhg import HHG
#       5 from .hsic import Hsic
#
# File c:\Users\austi\OneDrive\Documents\github\networks-course\venv\lib\site-packages\hyppo\independence\dcorr.py:2, in <module>
#       1 import numpy as np
# ----> 2 from numba import jit
#       4 from ..tools import check_perm_blocks_dim, chi2_approx, compute_dist
#       5 from ._utils import _CheckInputs
#
# File c:\Users\austi\OneDrive\Documents\github\networks-course\venv\lib\site-packages\numba\__init__.py:200, in <module>
#     197     return False
#     199 _ensure_llvm()
# --> 200 _ensure_critical_deps()
#     202 # we know llvmlite is working as the above tests passed, import it now as SVML
#     203 # needs to mutate runtime options (sets the `-vector-library`).
#     204 import llvmlite
#
# File c:\Users\austi\OneDrive\Documents\github\networks-course\venv\lib\site-packages\numba\__init__.py:140, in _ensure_critical_deps()
#     138     raise ImportError("Numba needs NumPy 1.18 or greater")
#     139 elif numpy_version > (1, 21):
# --> 140     raise ImportError("Numba needs NumPy 1.21 or less")
#     142 try:
#     143     import scipy
#
# ImportError: Numba needs NumPy 1.21 or less

# %% [markdown]
# # Display network
# ## Austin Larson

# %% [markdown]
# ### Load network
# This dataset is stored in two separate files. One tsv shows all hyperlinks in title, while the other has in body of message. I (for now) only use the title file, which should have a more correlated relationship. All information on the data can be found at the following website:
# https://snap.stanford.edu/data/soc-RedditHyperlinks.html
#
# The data is too large to visualize, so I will reduce it to just a single year (2014). I also simplified it by guaranteeing cutting out the useless data.

# %%
title = pd.read_csv(r'C:\Users\austi\Downloads\soc-redditHyperlinks-title.tsv', sep='\t')
title['TIMESTAMP'] = pd.to_datetime(title['TIMESTAMP'], infer_datetime_format=True)
title = title.drop(labels=['POST_ID', 'PROPERTIES'], axis=1)
title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571927 entries, 0 to 571926
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   SOURCE_SUBREDDIT  571927 non-null  object
#  1   TARGET_SUBREDDIT  571927 non-null  object
#  2   TIMESTAMP         571927 non-null  datetime64[ns]
#  3   LINK_SENTIMENT    571927 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 17.5+ MB

# %%
title['year'] = pd.DatetimeIndex(title['TIMESTAMP']).year
title['month'] = pd.DatetimeIndex(title['TIMESTAMP']).month
title = title[(title['year'] == 2014) & (title['month'] == 1)]
title = title.drop(['TIMESTAMP', 'year', 'month'], axis=1)
title = title[title['LINK_SENTIMENT'] == 1]
title = title.drop_duplicates()

title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6473 entries, 7 to 338046
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SOURCE_SUBREDDIT  6473 non-null   object
#  1   TARGET_SUBREDDIT  6473 non-null   object
#  2   LINK_SENTIMENT    6473 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 202.3+ KB

# %%
g = nx.convert_matrix.from_pandas_edgelist(
    df = title, 
    source = "SOURCE_SUBREDDIT", 
    target = "TARGET_SUBREDDIT",
    edge_attr = "LINK_SENTIMENT",
    create_using=nx.DiGraph
)
nodelist = list(g.nodes)
A = nx.to_numpy_array(g, nodelist)
len(nodelist)
# Out:
# 3810

# %% [markdown]
# ### Display network
# #### Heatmap
# I run into issues using heatmaps, since this is a rather large dataset, so I cannot glean much information as a heatmap. However, since I assume you would like to see one, here's a sample.

# %%
sns.heatmap(A[:1000, :1000])
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Node display
# Using a display made in NetworkX, I can hopefully see something a little more clear.

# %%
nx.draw_networkx(g, with_labels=False, node_size=1, arrows=False, width=0.2, linewidths=0.2)

# %%
nx.draw_kamada_kawai(g, with_labels=False, node_size=1, arrows=False, width=0.2, linewidths=0.2)

# %%
len(nodelist)
# Out:
# 3810
